# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir('/content')

# %%
data=pd.read_csv("hrdata.csv")

# %%
data2=pd.read_csv("MMix.csv")

# %%
data3=pd.read_csv("iris.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of       EmployeeCount  EmployeeID              Department  \
# 0                 1           1                   Sales
# 1                 1           2  Research & Development
# 2                 1           4  Research & Development
# 3                 1           5  Research & Development
# 4                 1           7  Research & Development
# ...             ...         ...                     ...
# 1465              1        2061  Research & Development
# 1466              1        2062  Research & Development
# 1467              1        2064  Research & Development
# 1468              1        2065                   Sales
# 1469              1        2068  Research & Development
#
#                         JobRole Attrition  Gender  Age MaritalStatus  \
# 0               Sales Executive       Yes  Female   41        Single
# 1            Research Scientist        No    Male   49       Married
# 2         Laboratory Technician       Yes    Male   37        Single
# 3            Research Scientist        No  Female   33       Married
# 4         Laboratory Technician        No    Male   27       Married
# ...                         ...       ...     ...  ...           ...
# 1465      Laboratory Technician        No    Male   36       Married
# 1466  Healthcare Representative        No    Male   39       Married
# 1467     Manufacturing Director        No    Male   27       Married
# 1468            Sales Executive        No    Male   49       Married
# 1469      Laboratory Technician        No    Male   34       Married
#
#           Education EducationField  ... Hourlyrate Income  Salaryhike  \
# 0           College  Life Sciences  ...         94   5993          11
# 1     Below College  Life Sciences  ...         61   5130          23
# 2           College          Other  ...         92   2090          15
# 3            Master  Life Sciences  ...         56   2909          11
# 4     Below College        Medical  ...         40   3468          12
# ...             ...            ...  ...        ...    ...         ...
# 1465        College        Medical  ...         41   2571          17
# 1466  Below College        Medical  ...         42   9991          15
# 1467       Bachelor  Life Sciences  ...         87   6142          20
# 1468       Bachelor        Medical  ...         63   5390          14
# 1469       Bachelor        Medical  ...         82   4404          12
#
#      OverTime  Workex  YearsSinceLastPromotion  EmpSatisfaction  \
# 0         Yes       8                        0           Medium
# 1          No      10                        1             High
# 2         Yes       7                        0        Very High
# 3         Yes       8                        3        Very High
# 4          No       6                        2              Low
# ...       ...     ...                      ...              ...
# 1465       No      17                        0             High
# 1466       No       9                        1        Very High
# 1467      Yes       6                        0           Medium
# 1468       No      17                        0        Very High
# 1469       No       6                        1           Medium
#
#      TrainingTimesLastYear  WorkLifeBalance  Performance_Rating
# 0                        0              Bad           Excellent
# 1                        3           Better         Outstanding
# 2                        3           Better           Excellent
# 3                        3           Better           Excellent
# 4                        3           Better           Excellent
# ...                    ...              ...                 ...
# 1465                     3           Better           Excellent
# 1466                     5           Better           Excellent
# 1467                     0           Better         Outstanding
# 1468                     3             Good           Excellent
# 1469                     3             Best           Excellent
#
# [1470 rows x 24 columns]>

# %%
data2.head
# Out:
# <bound method NDFrame.head of      NewVolSales  Base Price  Radio     TV   InStore  Facebook  Twitter  \
# 0          19564   15.029276   245.0  145.4   15.452         0        0
# 1          19387   15.029276   314.0   66.0   16.388         0        0
# 2          23889   14.585093   324.0  155.1   62.692         0        0
# 3          20055   15.332887   298.0  114.5   16.573         0        0
# 4          20064   15.642632   279.0   96.5   41.504         0        0
# ..           ...         ...     ...    ...      ...       ...      ...
# 99         18335   15.958634   292.0   24.1   29.485         0        0
# 100        19054   15.642632     NaN  162.3   48.611         0        0
# 101        18198   15.958634     NaN  194.9   29.323         0        0
# 102        20495   15.642632     NaN  159.2   50.935         0        0
# 103        18169   16.281020     NaN  161.1   46.169         0        0
#
#      WebCamp  Online Website Campaign   ...      tvst60      tvst70  \
# 0          0       0               NaN  ...   87.240000  101.780000
# 1          0       0               NaN  ...   74.496000   76.734000
# 2          0       0               NaN  ...  122.858400  131.590200
# 3          0       0               NaN  ...  117.843360  119.627060
# 4          0       0               NaN  ...  105.037344  103.438118
# ..       ...     ...               ...  ...         ...         ...
# 99         0       0               NaN  ...   84.898962   71.611508
# 100        0       0               NaN  ...  131.339585  135.093453
# 101        0       0               NaN  ...  169.475834  176.958036
# 102        0       0               NaN  ...  163.310334  164.527411
# 103        0       0               NaN  ...  161.984133  162.128223
#
#          tvst80      tvst90   radiost30   radiost60   radiost70   radiost80  \
# 0    116.320000  130.860000   73.500000  147.000000  171.500000  196.000000
# 1     76.064000   72.486000  145.650000  247.200000  271.250000  290.400000
# 2    139.292800  146.838600  199.155000  293.280000  308.175000  317.280000
# 3    119.458560  117.733860  228.808500  296.112000  301.052500  301.856000
# 4    101.091712   98.623386  243.865950  285.844800  285.615750  283.571200
# ..          ...         ...         ...         ...         ...         ...
# 99    56.914647   40.925503  257.228689  279.449752  284.168883  287.783964
# 100  141.222929  150.162550  273.660082  298.979901  303.650665  307.156793
# 101  184.164586  190.426255  286.062058  308.591960  311.595199  313.431358
# 102  164.192917  162.322625  303.143440  329.236784  333.578560  337.086272
# 103  161.718583  161.222263  311.200408  329.694714  331.073568  331.417254
#
#       radiost90    Stout
# 0    220.500000  2.28342
# 1    304.650000  2.22134
# 2    322.065000  2.00604
# 3    300.406500  2.19897
# 4    281.140650  1.81860
# ..          ...      ...
# 99   290.365628  3.08540
# 100  309.836563  2.65688
# 101  314.483656  2.92802
# 102  340.148366  2.53958
# 103  331.014837  2.66790
#
# [104 rows x 24 columns]>

# %%
data3.head
# Out:
# <bound method NDFrame.head of      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
data.columns
# Out:
# Index(['EmployeeCount', 'EmployeeID', 'Department', 'JobRole', 'Attrition',
#        'Gender', 'Age', 'MaritalStatus', 'Education', 'EducationField',
#        'BusinessTravel', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'Hourlyrate', 'Income', 'Salaryhike', 'OverTime', 'Workex',
#        'YearsSinceLastPromotion', 'EmpSatisfaction', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'Performance_Rating'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %%
plt.hist(data.Income, bins = 10, alpha = 0.8, color = "navy", linewidth=3)
#orientation = 'horizontal'
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
from matplotlib import style

# %%
style.use('fivethirtyeight')
plt.hist(data.Income, bins = 10, alpha = 0.8, color = "navy", linewidth=3)
#orientation = 'horizontal'
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
data.Income.plot(kind='density', ls='-') #style
plt.xlabel("Income")
plt.title("Density Plot for Income")
plt.rcParams['xtick.labelsize']=8
plt.tight_layout()
plt.show()

# %%
ax = data['Income'].plot(kind='hist',color='green',ylim=(0,400))
ax2 = data['Income'].plot(kind='density',secondary_y=True,color='red', ax=ax, ls='--')

ax.set_ylabel('No. of Employees')
ax2.set_ylabel('Density')

# For better pdf plots - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.boxplot(data['Income'] ,  patch_artist=True, vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f676131e1f0>,
#   <matplotlib.lines.Line2D at 0x7f676131e550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f676131e8b0>,
#   <matplotlib.lines.Line2D at 0x7f676131ec10>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f6761310e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f676131ef70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f67613292b0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import pandas
style.use('fivethirtyeight')
data3.plot(kind='box',  color = 'red', subplots=True, layout=(2,2), sharex=False)
plt.tight_layout()
plt.show()

# %%
ax = sns.boxplot(data=data3, orient="h", palette="Set1")

# %%
bp = plt.boxplot(data['Income'])
bp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6760cbe5e0>,
#   <matplotlib.lines.Line2D at 0x7f6760cbe940>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6760cbeca0>,
#   <matplotlib.lines.Line2D at 0x7f6760cc6040>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6760cbe280>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6760cc63a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6760cc66a0>],
#  'means': []}

# %%
a=bp['fliers'][0]

# %%
type(a.get_data()[1])
# Out:
# numpy.ndarray

# %%
a.get_data()[1]
# Out:
# array([19094, 18947, 19545, 18740, 18844, 18172, 17328, 16959, 19537,
#        17181, 19926, 19033, 18722, 19999, 16792, 19232, 19517, 19068,
#        19202, 19436, 16872, 19045, 19144, 17584, 18665, 17068, 19272,
#        18300, 16659, 19406, 19197, 19566, 18041, 17046, 17861, 16835,
#        16595, 19502, 18200, 16627, 19513, 19141, 19189, 16856, 19859,
#        18430, 17639, 16752, 19246, 17159, 17924, 17099, 17444, 17399,
#        19419, 18303, 19973, 19845, 17650, 19237, 19627, 16756, 17665,
#        16885, 17465, 19626, 19943, 18606, 17048, 17856, 19081, 17779,
#        19740, 18711, 18265, 18213, 18824, 18789, 19847, 19190, 18061,
#        17123, 16880, 17861, 19187, 19717, 16799, 17328, 19701, 17169,
#        16598, 17007, 16606, 19586, 19331, 19613, 17567, 19049, 19658,
#        17426, 17603, 16704, 19833, 19038, 19328, 19392, 19665, 16823,
#        17174, 17875, 19161, 19636, 19431, 18880])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = axes[0].boxplot(data['Age'])
                         
# notch shape box plot
bplot2 = axes[1].boxplot(data['Income'])

plt.show()
plt.savefig('matplotlib.png')

# %%
plt.bar(data3['Species'], data3['Sepal.Length'], width = 0.3, color = 'pink',  align='center')
plt.bar(data3['Species'], data3['Sepal.Width'], width = 0.3, color = 'lightblue',  align='center')
plt.legend(loc=1)
plt.tight_layout()
plt.show()

# %%
plt.barh(data['Gender'], data['Income'], color = 'pink')

# %%
plt.plot(data2['NewVolSales'])
plt.xlabel("Week")
plt.ylabel("Volume Sales in thousands")
plt.title("Volume Sales")
# Out:
# Text(0.5, 1.0, 'Volume Sales')

# %%
plt.plot(data2['NewVolSales'], c = 'm', ls = "--", marker = "s", ms = 6)
plt.xticks(rotation = 'vertical')
plt.xlabel('Volume Sales in 1000 units')
plt.show()

# %%
type(plt.subplots())
# Out:
# tuple

# %%
fig, ax1 = plt.subplots()
ax1.plot(data2['NewVolSales'])
ax1.set_xlabel('time (w)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Volume Sales')

ax2 = ax1.twinx()
ax2.plot(data2['Radio '], 'r')
ax2.set_ylabel('Radio')

fig.tight_layout()
plt.show()

# %%
plt.scatter(x=data['Age'],y = data['Income'], color = "magenta", alpha = 0.5)
plt.title('Relationship Between Age and Income')
plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
sns.FacetGrid(col='Department',col_wrap=50,aspect=1.2,height=4,data=data).map(plt.scatter, 'Age', 'Income', s=20).fig.subplots_adjust(wspace=.3, hspace=.2)

# %%
sns.FacetGrid(col='Department',col_wrap=25,aspect=.8,height=4,data=data).map(plt.scatter, 'Age', 'Income')

# %%
style.use('classic')
g = sns.FacetGrid(data, col="MaritalStatus", row= "Gender", col_order=["Single", "Married","Divorced"])
g = g.map(plt.hist, "Income", bins=20, color="m")
g

# %%
kws = dict(s=50, linewidth=.5, edgecolor="w")
g = sns.FacetGrid(data, col="MaritalStatus", hue="Gender", palette="Set1",
                  hue_order=["Male", "Female"])
g = (g.map(plt.scatter, "Age", "Income", **kws).add_legend())

# %%
# Create a figure with 1x2 subplot and make the left subplot active
plt.subplot(1, 2, 1) 

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.scatter(data['Age'], data['Income'], color='b')
plt.title('Scatter')

# Make the right subplot active in the current 1x2 subplot grid
plt.subplot(1, 2, 2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.boxplot(data['Income'])
plt.title('Boxplot')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.subplots_adjust(hspace=0.4,wspace=0.4)

plt.subplot(1, 2, 1) 
plt.plot(data2['NewVolSales'], c = 'm', ls = "--", marker = "s", ms = 6)
plt.xticks(rotation = 'vertical')
plt.title('Volume Sales in 1000 units')

plt.subplot(1, 2, 2) 
plt.scatter(data2['NewVolSales'], data2['Base Price'], color='blue')
plt.title('NewVolSales vs. Base Price')

plt.tight_layout()
plt.show()

# %%
img = plt.imread('a.webp')
print(img.shape)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# (533, 800, 3)

# %%
img = plt.imread('v.webp')
print(img.shape)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# (148, 188, 4)

# %%
img = plt.imread('d.png')
print(img.shape)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# (360, 360, 3)
